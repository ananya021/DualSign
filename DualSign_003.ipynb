# %%
import json
import os
import shutil
import sys

import cv2
from tqdm import tqdm

# global variables
PATH_JSON = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_v0.3.json'


def main():
    try:
        # command line inputs
        path_dataset = r'C:\Users\anany\Downloads\WLASL-dataset-sample\videos'
        glosses = 20
        if not 1 <= glosses <= 2000:
            raise ValueError('\nInsert an integer: 1~2000')

        # set the name of dir that will contain the spilt
        path_k_glosses_dir = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_' + str(glosses) + '/'

        print('[log] > START DATASET PROCESSING ...\n')
        dataset_processing(glosses, path_k_glosses_dir, path_dataset)
        show_info(path_k_glosses_dir)
        print('\n[log] > DONE!')

    except ValueError:
        print('Insert an integer: 1~2000')


def dataset_processing(glosses, path_k_glosses_dir, path_dataset):
    # read the json as a list of dictionaries
    wlasl_json = read_json(PATH_JSON)

    # split the videos in train, val and test
    splitted_videos = splitting_train_val_test(wlasl_json, glosses)

    # create dirs in which we'll store the videos
    make_target_dirs(wlasl_json, glosses, path_k_glosses_dir)

    # copy the videos in their own dir
    save_in_dirs(path_dataset, path_k_glosses_dir, splitted_videos)


def read_json(file_path):
    with open(file_path) as f:
        wlasl_json = json.load(f)
    return wlasl_json


def splitting_train_val_test(json_file, glosses):
    print('[log] > Splitting videos in train, val and test ...')
    # save in a dictionary the 'video_id' - ['target_dit', ] pair
    videos_dict = {}
    for k, gloss in tqdm(enumerate(json_file)):  # iterate through each gloss
        if k < glosses:
            videos = gloss['instances']  # get all videos as array
            for video in videos:
                video_id = video['video_id']
                target_dir = video['split']  # get destination dir
                gloss_name = gloss['gloss']
                videos_dict[video_id] = (target_dir, gloss_name)
        else:
            break

    return videos_dict


def save_in_dirs(path_dataset, path_k_glosses_dir, videos):
    print('\n[log] > Copying videos to their respective directories ...')
    # Iterate through each video and copy it to the target directory
    for video_id, data in tqdm(videos.items()):
        source_url = os.path.join(path_dataset, f'{video_id}.mp4')
        destination_dir = os.path.join(path_k_glosses_dir, data[0], data[1])
        
        # Ensure the destination directory exists
        os.makedirs(destination_dir, exist_ok=True)
        
        try:
            # Attempt to copy the video file
            shutil.copy(source_url, destination_dir)
        except FileNotFoundError:
            # Log and skip if the video file is not found
            print(f'[warn] Skipping missing video: {video_id}')



def make_target_dirs(json_file, glosses, path_k_glosses_dir):
    # delete the existing target dir, if it exists
    if os.path.isdir('./' + path_k_glosses_dir):
        shutil.rmtree(path_k_glosses_dir)

    # create the target dir
    os.mkdir(path_k_glosses_dir)
    # create the train, val and test dirs
    os.mkdir(path_k_glosses_dir + 'train')
    os.mkdir(path_k_glosses_dir + 'val')
    os.mkdir(path_k_glosses_dir + 'test')

    print('\n[log] > Creating dirs ...')
    for k, gloss in tqdm(enumerate(json_file)):  # iterate through each gloss
        if k < glosses:
            # create as many folders as there are glosses
            os.mkdir(path_k_glosses_dir + 'train/' + gloss['gloss'])
            os.mkdir(path_k_glosses_dir + 'val/' + gloss['gloss'])
            os.mkdir(path_k_glosses_dir + 'test/' + gloss['gloss'])
        else:
            break


def show_info(path_k_glosses_dir):
    # print the numbers of videos
    print_entries(path_k_glosses_dir)

    # print the videos info
    print_videos_info(path_k_glosses_dir)


def print_entries(path_root):
    path_train = path_root + 'train/'
    path_val = path_root + 'val/'
    path_test = path_root + 'test/'

    n_tot = sum([len(files) for _, _, files in os.walk(path_root)])
    n_train = sum([len(files) for _, _, files in os.walk(path_train)])
    n_val = sum([len(files) for _, _, files in os.walk(path_val)])
    n_test = sum([len(files) for _, _, files in os.walk(path_test)])

    print('\n[log] > Dataset summary:')
    print(f'Total videos: {n_tot}')
    print(f'Videos in train: {n_train} - {(n_train / n_tot * 100):,.0f}%')
    print(f'Videos in val:   {n_val} - {(n_val / n_tot * 100):,.0f}%')
    print(f'Videos in test:  {n_test} - {(n_test / n_tot * 100):,.0f}%')


def print_videos_info(path_root):
    videos = get_videos_path(path_root)
    info = get_videos_info(videos)

    print('\n[log] > Dataset info:')
    print(
        f'The video {info[0][0]} has the MIN length: {info[0][1]} - '
        f'Total frames: {info[0][2]}'
    )
    print(
        f'The video {info[-1][0]} has the MAX length: {info[-1][1]} - '
        f'Total frames: {info[-1][2]}'
    )


def get_videos_path(path_root):
    # get videos path
    paths = []
    for root, dirs, files in os.walk(os.path.relpath(path_root)):
        for file in files:
            paths.append(os.path.join(root, file))

    return paths


def get_videos_info(videos):
    print('\n[log] > Retrieving videos metadata ...')
    lengths = [get_meta_data(vid_path) for vid_path in tqdm(videos)]

    return sorted(lengths, key=lambda x: x[1])  # sorted by duration


def get_meta_data(file_path):
    video_cap = cv2.VideoCapture(file_path)
    fps = video_cap.get(cv2.CAP_PROP_FPS)
    frame_count = int(video_cap.get(cv2.CAP_PROP_FRAME_COUNT))
    duration = frame_count / fps
    video_cap.release()

    file_name = os.path.basename(os.path.normpath(file_path))
    return file_name, duration, frame_count


if __name__ == '__main__':
    main()

# %%
import itertools
import os

import cv2
import numpy as np
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator


class VideoFrameGenerator(keras.utils.Sequence):
    """
    The VideoFrameGenerator extracts n frames from a video.

    You can choose between two sampling mode:
    - Mode 1: extracts n frames from the entire video.
    - Mode 2: extracts n frames from the entire video, but first performs a
    pre-sampling to eliminate the initial and final sequences in witch no
    movements appear.
    """

    def __init__(self, list_IDs, labels, batch_size=32, dim=(32, 32),
                 n_channels=3, n_sequence=10, shuffle=True, type_gen='train'):
        """Initialization"""
        self.dim = dim
        self.batch_size = batch_size
        self.labels = labels
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.n_sequence = n_sequence  # number of frames to extract
        self.shuffle = shuffle
        self.type_gen = type_gen
        self.sampl_mode = '2'
        self.aug_gen = ImageDataGenerator()
        print(f'Videos: {len(self.list_IDs)}, batches per epoch: '
              f'{int(np.floor(len(self.list_IDs) / self.batch_size))}')
        self.on_epoch_end()

    def __len__(self):
        """Denotes the number of batches per epoch"""
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __getitem__(self, index):
        """Generate one batch of data"""
        # Generate indexes of the batch
        indexes = self.indexes[
                  index * self.batch_size:(index + 1) * self.batch_size]
        # Find list of IDs
        list_IDs_temp = [self.list_IDs[k] for k in indexes]
        # Generate data
        X, y = self.__data_generation(list_IDs_temp)

        return X, y

    def frame_sampling(self, len_frames):
        """
        Sample the video with the chosen policy.

        :param len_frames: video length (in frames)
        :return: the indexes of the sampled frames.
        """
        # create a list of frames
        frames = list(range(len_frames))

        # sampling choice
        if self.sampl_mode == '1':
            # create chunks
            chunks = list(self.get_chunks(frames, self.n_sequence))
            sampling = self.sampling_mode_1(chunks)
        elif self.sampl_mode == '2':
            sampling = self.sampling_mode_2(frames, self.n_sequence)
        else:
            raise ValueError

        return sampling

    def sampling_mode_1(self, chunks):
        """
        Select 10 frames from the entire sequence.

        :param chunks: blocks from which to select frames.
        :return: the indexes of the 10 frames sampled.
        """
        sampling = []
        for i, chunk in enumerate(chunks):
            if i == 0 or i == 1:
                sampling.append(chunk[-1])  # get the last frame
            elif i == (len(chunks) - 1) or i == (len(chunks) - 2):
                sampling.append(chunk[0])  # get the first frame
            else:
                sampling.append(chunk[len(chunk) // 2])  # get the central frame

        return sampling

    def sampling_mode_2(self, frames, n_sequence):
        """
        Do a pre-sampling by creating 12 chunks. Then apply the first sampling
        mode (sampling_mode_1 function).

        :param frames: list of frames.
        :param n_sequence: number of frames to sample.
        :return: the indexes of the 10 frames sampled.
        """
        # create 12 chunks
        chunks = list(self.get_chunks(frames, 12))

        # remove the first and the last chunk
        sub_chunks = chunks[1:-1]

        # get a the new list of frames
        sub_frame_list = list(itertools.chain.from_iterable(sub_chunks))

        # create n_sequence(10) chunks
        new_chunks = list(self.get_chunks(sub_frame_list, n_sequence))

        sampling = self.sampling_mode_1(new_chunks)

        return sampling

    def get_chunks(self, l, n):
        # divide indexes list in n chunks
        k, m = divmod(len(l), n)
        return (l[i * k + min(i, m):(i + 1) * k + min(i + 1, m)] for i in
                range(n))

    def __data_generation(self, list_IDs_temp):
        """Generates data containing batch_size samples"""
        # Initialization
        X = np.empty((self.batch_size, self.n_sequence, *self.dim, self.n_channels))
        Y = np.empty((self.batch_size), dtype=int)

        for i, ID in enumerate(list_IDs_temp):  # ID: path to file
            path_file = ID
            cap = cv2.VideoCapture(path_file)
            if not cap.isOpened():
                print(f"Warning: Unable to open video file: {path_file}")
                continue  # Skip this video if it cannot be opened
        
            # get number of frames
            length_file = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            if length_file == 0:
                print(f"Warning: Video file is empty or has zero frames: {path_file}")
                cap.release()
                continue  # Skip this video
        
            index_sampling = self.frame_sampling(length_file)  # sampling indexes

            for j, n_pic in enumerate(index_sampling):
                cap.set(cv2.CAP_PROP_POS_FRAMES, n_pic)  # jump to that index
                ret, frame = cap.read()
                if not ret or frame is None:
                    print(f"Warning: Empty or invalid frame at index {n_pic} in video: {path_file}")
                    continue  # Skip this frame
            
                try:
                    new_image = cv2.resize(frame, self.dim)
                    X[i, j, :, :, :] = new_image
                except Exception as e:
                    print(f"Error resizing frame at index {n_pic} in video: {path_file}: {e}")
                    continue

            if self.type_gen == 'train':
                X[i,] = self.sampling_augmentation(X[i,]) / 255.0
            else:
                X[i,] = X[i,] / 255.0

            Y[i] = self.labels[ID]
            cap.release()

            # Debugging: Uncomment to save sampled frames for inspection
            # self.save_frame_sampling(X, i, ID, len(index_sampling))

        return X, Y


    def sampling_augmentation(self, sequence):
        """
        - `'theta'`: Float. Rotation angle in degrees.
        - `'tx'`: Float. Shift in the x direction. - vertical shift (height)
        - `'ty'`: Float. Shift in the y direction. - horizontal shift (width)
        - `'shear'`: Float. Shear angle in degrees.
        - `'zx'`: Float. Zoom in the x direction. - vertical zoom
        - `'zy'`: Float. Zoom in the y direction. - horizontal zoom
        - `'flip_horizontal'`: Boolean. Horizontal flip.
        - `'flip_vertical'`: Boolean. Vertical flip.
        - `'channel_shift_intensity'`: Float. Channel shift intensity.
        - `'brightness'`: Float. Brightness shift intensity.
        """
        transformations = ['theta', 'tx', 'ty', 'zx', 'zy', 'flip_horizontal',
                           'brightness']

        # random choice of number of transformations
        random_transforms = np.random.randint(2, 4)  # min 2 - max 3
        # random choice of transformations
        transforms_idxs = np.random.choice(len(transformations),
                                           random_transforms, replace=False)

        transfor_parameters = {}
        for idx in transforms_idxs:
            if transformations[idx] == 'theta':
                transfor_parameters['theta'] = np.random.randint(-5, 5)

            elif transformations[idx] == 'tx':
                transfor_parameters['tx'] = np.random.randint(-10, 10)

            elif transformations[idx] == 'ty':
                transfor_parameters['ty'] = np.random.randint(-15, 15)

            elif transformations[idx] == 'zx':
                transfor_parameters['zx'] = np.random.uniform(0.6, 1.05)

            elif transformations[idx] == 'zy':
                transfor_parameters['zy'] = np.random.uniform(0.6, 1.05)

            elif transformations[idx] == 'flip_horizontal':
                transfor_parameters['flip_horizontal'] = True

            elif transformations[idx] == 'brightness':
                transfor_parameters['brightness'] = np.random.uniform(0.4, 0.6)

        len_seq = sequence.shape[0]
        for i in range(len_seq):
            sequence[i] = self.aug_gen.apply_transform(sequence[i],
                                                       transfor_parameters)

        return sequence

    def save_frame_sampling(self, samp_imgs, i, img_path, n_frames):
        # concatenate all frames
        train_frame = ()
        for n_f in range(n_frames):
            train_frame = (*train_frame, samp_imgs[i, n_f,] * 255.0)

        # get the train of frame in one image
        full_img = np.concatenate(train_frame, axis=1)

        # info
        img_name = (os.path.split(img_path)[1])[:-4]
        img_label = os.path.split(os.path.split(img_path)[0])[1]

        # save the image
        if not os.path.isdir('./sampling_test/'):
            os.mkdir('./sampling_test/')

        name_file = self.type_gen + '_' + img_label + '_' + img_name
        cv2.imwrite('./sampling_test/' + name_file + '.jpg', full_img)

print("Done")
# Out:
# Done

# %%
"""
The proposed models are valid for the WLASL20custom, WLASL100, WLASL300,
WLASL1000 and WLASL2000 datasets.
"""
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.layers import TimeDistributed, GRU, BatchNormalization
from tensorflow.keras.models import Sequential


def create_model_wlasl20c(frames, width, height, channels, output):
    """
    Create the keras model.

    :param frames: frame number of the sequence.
    :param width: width of the image.
    :param height: height of the image.
    :param channels: 3 for RGB, 1 for B/W images.
    :param output: number of neurons for classification.
    :return: the keras model.
    """
    model = Sequential([
        # ConvNet
        TimeDistributed(
            MobileNetV2(weights='imagenet', include_top=False,
                        input_shape=[height, width, channels]),
            input_shape=[frames, height, width, channels]
        ),
        TimeDistributed(GlobalAveragePooling2D()),

        # GRUs
        GRU(256, return_sequences=True),
        BatchNormalization(),
        GRU(256),

        # Feedforward
        Dense(units=64, activation='relu'),
        Dropout(0.65),
        Dense(units=32, activation='relu'),
        Dropout(0.65),
        Dense(units=output, activation='softmax')
    ])

    return model


def create_model_wlasl100(frames, width, height, channels, output):
    """
    Create the keras model.

    :param frames: frame number of the sequence.
    :param width: width of the image.
    :param height: height of the image.
    :param channels: 3 for RGB, 1 for B/W images.
    :param output: number of neurons for classification.
    :return: the keras model.
    """
    model = Sequential([
        # ConvNet
        TimeDistributed(
            MobileNetV2(weights='imagenet', include_top=False,
                        input_shape=[height, width, channels]),
            input_shape=[frames, height, width, channels]
        ),
        TimeDistributed(GlobalAveragePooling2D()),

        # GRUs
        GRU(256, return_sequences=True),
        BatchNormalization(),
        GRU(256),

        # Feedforward
        Dense(units=200, activation='relu'),
        Dropout(0.66),
        Dense(units=150, activation='relu'),
        Dropout(0.66),
        Dense(units=output, activation='softmax')
    ])

    return model


def create_model_wlasl300(frames, width, height, channels, output):
    """
    Create the keras model.

    :param frames: frame number of the sequence.
    :param width: width of the image.
    :param height: height of the image.
    :param channels: 3 for RGB, 1 for B/W images.
    :param output: number of neurons for classification.
    :return: the keras model.
    """
    model = Sequential([
        # ConvNet
        TimeDistributed(
            MobileNetV2(weights='imagenet', include_top=False,
                        input_shape=[height, width, channels]),
            input_shape=[frames, height, width, channels]
        ),
        TimeDistributed(GlobalAveragePooling2D()),

        # GRUs
        GRU(256, return_sequences=True),
        BatchNormalization(),
        GRU(256),

        # Feedforward
        Dense(units=400, activation='relu'),
        Dropout(0.6),
        Dense(units=350, activation='relu'),
        Dropout(0.6),
        Dense(units=output, activation='softmax')
    ])

    return model


def create_model_wlasl1000(frames, width, height, channels, output):
    """
    Create the keras model.

    :param frames: frame number of the sequence.
    :param width: width of the image.
    :param height: height of the image.
    :param channels: 3 for RGB, 1 for B/W images.
    :param output: number of neurons for classification.
    :return: the keras model.
    """
    model = Sequential([
        # ConvNet
        TimeDistributed(
            MobileNetV2(weights='imagenet', include_top=False,
                        input_shape=[height, width, channels]),
            input_shape=[frames, height, width, channels]
        ),
        TimeDistributed(GlobalAveragePooling2D()),

        # GRUs
        GRU(256, return_sequences=True),
        BatchNormalization(),
        GRU(256),

        # Feedforward
        Dense(units=512, activation='relu'),
        Dropout(0.7),
        Dense(units=output, activation='softmax')
    ])

    return model


def create_model_wlasl2000(frames, width, height, channels, output):
    """
    Create the keras model.

    :param frames: frame number of the sequence.
    :param width: width of the image.
    :param height: height of the image.
    :param channels: 3 for RGB, 1 for B/W images.
    :param output: number of neurons for classification.
    :return: the keras model.
    """
    model = Sequential([
        # ConvNet
        TimeDistributed(
            MobileNetV2(weights='imagenet', include_top=False,
                        input_shape=[height, width, channels]),
            input_shape=[frames, height, width, channels]
        ),
        TimeDistributed(GlobalAveragePooling2D()),

        # GRUs
        GRU(256, return_sequences=True),
        BatchNormalization(),
        GRU(256),

        # Feedforward
        Dense(units=1000, activation='relu'),
        Dropout(0.75),
        Dense(units=output, activation='softmax')
    ])

    return model

print("Done")
# Out:
# Done

# %%
import glob
import os


def labels_to_number(base_path):
    """
    Map labels (folder names) to numeric values.
    """
    if not os.path.exists(base_path):
        print(f"Warning: Base path '{base_path}' does not exist. Skipping...")
        return {}
    
    labels = {}
    try:
        folders = [folder for folder in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, folder))]
        for idx, folder in enumerate(sorted(folders)):
            labels[folder] = idx
    except Exception as e:
        print(f"Error while processing labels: {e}")
    
    if not labels:
        print(f"Warning: No valid labels found in '{base_path}'.")
    return labels



def videos_to_dict(path, labels):
    """
    Read the videos and return a dict like {'path_to_video': 'label'}.
    """
    videos_dict = {}
    
    if not os.path.exists(path):
        print(f"Warning: Path '{path}' does not exist. Skipping...")
        return videos_dict
    
    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith(('.mp4', '.avi', '.mov')):  # Ensure only video files are considered
                video_name = os.path.join(root, file)
                dir_name = os.path.basename(os.path.dirname(video_name))  # Subdirectory as label
                
                if dir_name in labels:  # Check if the label exists
                    videos_dict[video_name] = labels[dir_name]
                else:
                    print(f"Warning: Directory '{dir_name}' not found in labels dictionary. Skipping...")
    
    if not videos_dict:
        print(f"Warning: No valid videos found in '{path}'.")
    return videos_dict

print("Done")
# Out:
# Done

# %%
import os
from itertools import islice

import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam


# model settings
height = 224
width = 224
dim = (height, width)
batch_size = 8
frames = 10
channels = 3
output = 20

TRAIN_PATH = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_20\train\\'
VAL_PATH = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_20\val\\'
TEST_PATH = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_20\test\\'

# transform labels from string to number
labels = labels_to_number(TRAIN_PATH)
print(f'Labels: {labels}')

# load dataset as dict
y_train_dict = videos_to_dict(TRAIN_PATH, labels)
y_val_dict = videos_to_dict(VAL_PATH, labels)
y_test_dict = videos_to_dict(TEST_PATH, labels)

print(f'\nTrain set: {len(y_train_dict)} videos - with labels')
print(f'Val   set: {len(y_val_dict)} videos - with labels')
print(f'Test  set: {len(y_test_dict)} videos - with labels')
print(f'Train set samples: {list(islice(y_train_dict.items(), 3))}')
print(f'Val   set samples: {list(islice(y_val_dict.items(), 3))}')
print(f'Test  set samples: {list(islice(y_test_dict.items(), 3))}')

# get video paths (without labels)
X_train = list(y_train_dict.keys())
X_val = list(y_val_dict.keys())
X_test = list(y_test_dict.keys())

print(f'\nTrain set: {len(X_train)} videos')
print(f'Val   set: {len(X_val)} videos')
print(f'Test  set: {len(X_test)} videos')
print(f'Train set samples: {X_train[:4]}')
print(f'Val   set samples: {X_val[:4]}')
print(f'Test  set samples: {X_test[:4]}')

# instantiation of generators for train and val sets
print('\nTrain generator')
train_generator = VideoFrameGenerator(
    list_IDs=X_train,
    labels=y_train_dict,
    batch_size=batch_size,
    dim=dim,
    n_channels=3,
    n_sequence=frames,
    shuffle=True,
    type_gen='train'
)

print('\nVal generator')
val_generator = VideoFrameGenerator(
    list_IDs=X_val,
    labels=y_val_dict,
    batch_size=batch_size,
    dim=dim,
    n_channels=3,
    n_sequence=frames,
    shuffle=True,
    type_gen='val'
)

# model building
print('\nModel building and compiling . . .')
model = create_model_wlasl20c(frames, width, height, channels, output)
model.summary()
# model compiling
adam = Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-07,
            amsgrad=False, name="Adam")
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

# callbacks creation
if not os.path.isdir('./saved_models/'):
    os.mkdir('./saved_models/')

# save the best model each time
path = './saved_models/'
checkpoint_cb = ModelCheckpoint(path + 'best_model.keras', save_best_only=True)

# start training
print('\nStart training . . .')
learn_epochs = 300
history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=learn_epochs,
                    callbacks=[checkpoint_cb])

# save learning curves
if not os.path.isdir('./plots/'):
    os.mkdir('./plots/')

print('\nSaving learning curves graph . . .')
pd.DataFrame(history.history).plot(figsize=(9, 6))
plt.grid(True)
plt.gca().set_ylim(0, 4)
plt.savefig('./plots/learning_curves.png')
# Out:
# Labels: {'all': 0, 'before': 1, 'black': 2, 'book': 3, 'candy': 4, 'chair': 5, 'clothes': 6, 'computer': 7, 'cousin': 8, 'deaf': 9, 'drink': 10, 'fine': 11, 'go': 12, 'help': 13, 'no': 14, 'thin': 15, 'walk': 16, 'who': 17, 'year': 18, 'yes': 19}
#
# Train set: 167 videos - with labels
# Val   set: 38 videos - with labels
# Test  set: 26 videos - with labels
# Train set samples: [('C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\train\\\\all\\01987.mp4', 0), ('C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\train\\\\all\\01988.mp4', 0), ('C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\train\\\\all\\01991.mp4', 0)]
# Val   set samples: [('C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\val\\\\before\\05750.mp4', 1), ('C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\val\\\\black\\06476.mp4', 2), ('C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\val\\\\black\\69236.mp4', 2)]
# Test  set samples: [('C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\test\\\\all\\01986.mp4', 0), ('C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\test\\\\before\\05727.mp4', 1), ('C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\test\\\\before\\05739.mp4', 1)]
#
# Train set: 167 videos
# Val   set: 38 videos
# Test  set: 26 videos
# Train set samples: ['C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\train\\\\all\\01987.mp4', 'C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\train\\\\all\\01988.mp4', 'C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\train\\\\all\\01991.mp4', 'C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\train\\\\all\\01992.mp4']
# Val   set samples: ['C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\val\\\\before\\05750.mp4', 'C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\val\\\\black\\06476.mp4', 'C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\val\\\\black\\69236.mp4', 'C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\val\\\\book\\07099.mp4']
# Test  set samples: ['C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\test\\\\all\\01986.mp4', 'C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\test\\\\before\\05727.mp4', 'C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\test\\\\before\\05739.mp4', 'C:\\Users\\anany\\Downloads\\WLASL-dataset-sample\\WLASL_20\\test\\\\before\\05741.mp4']
#
# Train generator
# Videos: 167, batches per epoch: 20
#
# Val generator
# Videos: 38, batches per epoch: 4
#
# Model building and compiling . . .
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_6              │ (None, 10, 7, 7, 1280) │     2,257,984 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_7              │ (None, 10, 1280)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_6 (GRU)                     │ (None, 10, 256)        │     1,181,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 10, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_7 (GRU)                     │ (None, 256)            │       394,752 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 20)             │           660 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,854,132 (14.70 MB)
#  Trainable params: 3,819,508 (14.57 MB)
#  Non-trainable params: 34,624 (135.25 KB)
# Start training . . .
# Epoch 1/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 350s 10s/step - accuracy: 0.0488 - loss: 3.6655 - val_accuracy: 0.0625 - val_loss: 2.9777
# Epoch 2/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 176s 9s/step - accuracy: 0.0381 - loss: 3.7601 - val_accuracy: 0.1250 - val_loss: 2.9921
# Epoch 3/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 179s 9s/step - accuracy: 0.0446 - loss: 3.5615 - val_accuracy: 0.0312 - val_loss: 3.0056
# Epoch 4/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 181s 9s/step - accuracy: 0.0285 - loss: 3.4841 - val_accuracy: 0.1250 - val_loss: 3.0035
# Epoch 5/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - accuracy: 0.0583 - loss: 3.3303 - val_accuracy: 0.0000e+00 - val_loss: 3.0363
# Epoch 6/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.0588 - loss: 3.2346 - val_accuracy: 0.0000e+00 - val_loss: 3.0383
# Epoch 7/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.0924 - loss: 3.0982 - val_accuracy: 0.0625 - val_loss: 3.0312
# Epoch 8/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 9s/step - accuracy: 0.0488 - loss: 3.1762 - val_accuracy: 0.0312 - val_loss: 2.9817
# Epoch 9/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 9s/step - accuracy: 0.0372 - loss: 3.1008 - val_accuracy: 0.0312 - val_loss: 3.0164
# Epoch 10/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.0287 - loss: 3.0900 - val_accuracy: 0.1562 - val_loss: 3.0098
# Epoch 11/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 9s/step - accuracy: 0.0974 - loss: 3.0488 - val_accuracy: 0.0312 - val_loss: 3.0115
# Epoch 12/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.0710 - loss: 3.0294 - val_accuracy: 0.0625 - val_loss: 2.9617
# Epoch 13/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.0688 - loss: 3.1044 - val_accuracy: 0.0625 - val_loss: 2.9773
# Epoch 14/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.0312 - loss: 3.0451 - val_accuracy: 0.0938 - val_loss: 2.9921
# Epoch 15/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.0708 - loss: 3.0149 - val_accuracy: 0.1250 - val_loss: 2.9983
# Epoch 16/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.0655 - loss: 3.0026 - val_accuracy: 0.0938 - val_loss: 2.9748
# Epoch 17/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.0501 - loss: 3.0290 - val_accuracy: 0.0938 - val_loss: 2.9465
# Epoch 18/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.0438 - loss: 3.0390 - val_accuracy: 0.1250 - val_loss: 2.9899
# Epoch 19/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.0400 - loss: 3.0046 - val_accuracy: 0.1250 - val_loss: 2.9856
# Epoch 20/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.0951 - loss: 3.0194 - val_accuracy: 0.0625 - val_loss: 2.9909
# Epoch 21/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.0546 - loss: 2.9972 - val_accuracy: 0.1250 - val_loss: 2.9731
# Epoch 22/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 9s/step - accuracy: 0.1144 - loss: 2.8858 - val_accuracy: 0.0625 - val_loss: 2.9648
# Epoch 23/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.0737 - loss: 3.0216 - val_accuracy: 0.0625 - val_loss: 2.9798
# Epoch 24/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - accuracy: 0.0501 - loss: 2.9704 - val_accuracy: 0.0938 - val_loss: 2.9706
# Epoch 25/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 9s/step - accuracy: 0.1136 - loss: 2.9011 - val_accuracy: 0.0625 - val_loss: 2.9914
# Epoch 26/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - accuracy: 0.0682 - loss: 2.8987 - val_accuracy: 0.1562 - val_loss: 2.9853
# Epoch 27/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 174s 9s/step - accuracy: 0.0795 - loss: 2.9818 - val_accuracy: 0.0625 - val_loss: 2.9759
# Epoch 28/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.0773 - loss: 2.9512 - val_accuracy: 0.0625 - val_loss: 2.9655
# Epoch 29/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - accuracy: 0.0783 - loss: 2.9671 - val_accuracy: 0.0938 - val_loss: 2.9542
# Epoch 30/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 8s/step - accuracy: 0.1084 - loss: 2.8635 - val_accuracy: 0.0625 - val_loss: 2.9807
# Epoch 31/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.0812 - loss: 3.0052 - val_accuracy: 0.1562 - val_loss: 2.9604
# Epoch 32/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.1006 - loss: 2.8701 - val_accuracy: 0.0938 - val_loss: 2.9295
# Epoch 33/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.0798 - loss: 3.0451 - val_accuracy: 0.0938 - val_loss: 2.9502
# Epoch 34/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - accuracy: 0.0739 - loss: 2.9062 - val_accuracy: 0.1250 - val_loss: 2.9984
# Epoch 35/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.1080 - loss: 2.8760 - val_accuracy: 0.0625 - val_loss: 2.9611
# Epoch 36/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - accuracy: 0.1138 - loss: 2.9077 - val_accuracy: 0.0938 - val_loss: 2.9734
# Epoch 37/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - accuracy: 0.0752 - loss: 2.8676 - val_accuracy: 0.0625 - val_loss: 2.9812
# Epoch 38/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.1713 - loss: 2.8409 - val_accuracy: 0.0938 - val_loss: 2.9464
# Epoch 39/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.1079 - loss: 2.9488 - val_accuracy: 0.1250 - val_loss: 2.9569
# Epoch 40/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.0933 - loss: 2.9652 - val_accuracy: 0.0625 - val_loss: 3.0014
# Epoch 41/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.1377 - loss: 2.8846 - val_accuracy: 0.0000e+00 - val_loss: 3.0001
# Epoch 42/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.0959 - loss: 3.0203 - val_accuracy: 0.0625 - val_loss: 3.0217
# Epoch 43/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.1289 - loss: 2.8603 - val_accuracy: 0.0938 - val_loss: 2.9700
# Epoch 44/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.0974 - loss: 2.9197 - val_accuracy: 0.0938 - val_loss: 2.9849
# Epoch 45/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.1046 - loss: 2.9322 - val_accuracy: 0.1250 - val_loss: 2.9793
# Epoch 46/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - accuracy: 0.1569 - loss: 2.8393 - val_accuracy: 0.1250 - val_loss: 2.9619
# Epoch 47/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.1280 - loss: 2.7940 - val_accuracy: 0.1875 - val_loss: 2.9084
# Epoch 48/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.1231 - loss: 2.7767 - val_accuracy: 0.0938 - val_loss: 2.9297
# Epoch 49/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - accuracy: 0.1055 - loss: 2.7670 - val_accuracy: 0.0938 - val_loss: 2.9213
# Epoch 50/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.1231 - loss: 2.9826 - val_accuracy: 0.0938 - val_loss: 2.9359
# Epoch 51/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - accuracy: 0.1181 - loss: 2.7804 - val_accuracy: 0.1875 - val_loss: 2.9059
# Epoch 52/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.0918 - loss: 2.9179 - val_accuracy: 0.1250 - val_loss: 2.9458
# Epoch 53/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - accuracy: 0.1138 - loss: 2.9828 - val_accuracy: 0.1250 - val_loss: 2.9214
# Epoch 54/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 174s 9s/step - accuracy: 0.1639 - loss: 2.7257 - val_accuracy: 0.1875 - val_loss: 2.9211
# Epoch 55/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.1654 - loss: 2.8790 - val_accuracy: 0.1562 - val_loss: 2.9249
# Epoch 56/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.0872 - loss: 2.9657 - val_accuracy: 0.1562 - val_loss: 2.9463
# Epoch 57/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 174s 9s/step - accuracy: 0.1189 - loss: 2.7534 - val_accuracy: 0.2188 - val_loss: 2.9326
# Epoch 58/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.0953 - loss: 2.8950 - val_accuracy: 0.1562 - val_loss: 2.9328
# Epoch 59/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.0756 - loss: 2.8653 - val_accuracy: 0.1875 - val_loss: 2.9185
# Epoch 60/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 175s 9s/step - accuracy: 0.2016 - loss: 2.7019 - val_accuracy: 0.1562 - val_loss: 2.9406
# Epoch 61/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 8s/step - accuracy: 0.1143 - loss: 2.8451 - val_accuracy: 0.1875 - val_loss: 2.9126
# Epoch 62/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 175s 9s/step - accuracy: 0.0776 - loss: 2.8440 - val_accuracy: 0.1250 - val_loss: 2.9133
# Epoch 63/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.1710 - loss: 2.7514 - val_accuracy: 0.2188 - val_loss: 2.8804
# Epoch 64/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.1551 - loss: 2.8258 - val_accuracy: 0.2188 - val_loss: 2.9560
# Epoch 65/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.1166 - loss: 2.9055 - val_accuracy: 0.1562 - val_loss: 2.9413
# Epoch 66/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - accuracy: 0.1429 - loss: 2.8029 - val_accuracy: 0.2188 - val_loss: 2.9372
# Epoch 67/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - accuracy: 0.1233 - loss: 2.8034 - val_accuracy: 0.2188 - val_loss: 2.9876
# Epoch 68/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.1501 - loss: 2.8583 - val_accuracy: 0.1875 - val_loss: 2.9119
# Epoch 69/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.1846 - loss: 2.6964 - val_accuracy: 0.2188 - val_loss: 2.9346
# Epoch 70/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.2115 - loss: 2.6671 - val_accuracy: 0.1875 - val_loss: 2.8846
# Epoch 71/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - accuracy: 0.1075 - loss: 2.7779 - val_accuracy: 0.1875 - val_loss: 2.9577
# Epoch 72/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 163s 8s/step - accuracy: 0.1422 - loss: 2.7697 - val_accuracy: 0.2812 - val_loss: 2.8631
# Epoch 73/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 165s 8s/step - accuracy: 0.2132 - loss: 2.7108 - val_accuracy: 0.1562 - val_loss: 2.9098
# Epoch 74/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 165s 8s/step - accuracy: 0.1745 - loss: 2.7352 - val_accuracy: 0.3125 - val_loss: 2.8412
# Epoch 75/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 164s 8s/step - accuracy: 0.1831 - loss: 2.6940 - val_accuracy: 0.1250 - val_loss: 2.9132
# Epoch 76/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.1283 - loss: 2.6659 - val_accuracy: 0.0625 - val_loss: 2.9559
# Epoch 77/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 165s 8s/step - accuracy: 0.1625 - loss: 2.7588 - val_accuracy: 0.0625 - val_loss: 2.9588
# Epoch 78/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 9s/step - accuracy: 0.2131 - loss: 2.7168 - val_accuracy: 0.0938 - val_loss: 2.9401
# Epoch 79/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 9s/step - accuracy: 0.1378 - loss: 2.7158 - val_accuracy: 0.2188 - val_loss: 2.8812
# Epoch 80/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 175s 9s/step - accuracy: 0.1264 - loss: 2.9225 - val_accuracy: 0.2188 - val_loss: 2.8960
# Epoch 81/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 180s 9s/step - accuracy: 0.1900 - loss: 2.6330 - val_accuracy: 0.1250 - val_loss: 2.8688
# Epoch 82/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 179s 9s/step - accuracy: 0.1671 - loss: 2.8318 - val_accuracy: 0.1875 - val_loss: 2.8669
# Epoch 83/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 178s 9s/step - accuracy: 0.1403 - loss: 2.7009 - val_accuracy: 0.1562 - val_loss: 2.9412
# Epoch 84/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.1343 - loss: 2.6966 - val_accuracy: 0.1562 - val_loss: 2.8639
# Epoch 85/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 182s 9s/step - accuracy: 0.1537 - loss: 2.7378 - val_accuracy: 0.1250 - val_loss: 2.9948
# Epoch 86/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 175s 9s/step - accuracy: 0.2377 - loss: 2.6329 - val_accuracy: 0.1875 - val_loss: 2.9378
# Epoch 87/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 178s 9s/step - accuracy: 0.1819 - loss: 2.6276 - val_accuracy: 0.1875 - val_loss: 2.8800
# Epoch 88/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 175s 9s/step - accuracy: 0.2066 - loss: 2.6646 - val_accuracy: 0.2500 - val_loss: 2.8634
# Epoch 89/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 180s 9s/step - accuracy: 0.1441 - loss: 2.7434 - val_accuracy: 0.1250 - val_loss: 2.8772
# Epoch 90/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 174s 9s/step - accuracy: 0.1646 - loss: 2.7281 - val_accuracy: 0.1562 - val_loss: 2.8535
# Epoch 91/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.1660 - loss: 2.6500 - val_accuracy: 0.1250 - val_loss: 2.9728
# Epoch 92/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.1863 - loss: 2.6339 - val_accuracy: 0.1562 - val_loss: 2.8562
# Epoch 93/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 182s 9s/step - accuracy: 0.2368 - loss: 2.5292 - val_accuracy: 0.1875 - val_loss: 2.8750
# Epoch 94/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 184s 9s/step - accuracy: 0.1576 - loss: 2.6315 - val_accuracy: 0.0938 - val_loss: 2.9073
# Epoch 95/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 185s 9s/step - accuracy: 0.2738 - loss: 2.6315 - val_accuracy: 0.1562 - val_loss: 2.8900
# Epoch 96/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 179s 9s/step - accuracy: 0.2234 - loss: 2.5861 - val_accuracy: 0.2188 - val_loss: 2.8989
# Epoch 97/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 184s 9s/step - accuracy: 0.2087 - loss: 2.5290 - val_accuracy: 0.1875 - val_loss: 2.8423
# Epoch 98/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.1914 - loss: 2.6693 - val_accuracy: 0.1875 - val_loss: 2.8766
# Epoch 99/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 9s/step - accuracy: 0.2337 - loss: 2.5665 - val_accuracy: 0.2500 - val_loss: 2.7725
# Epoch 100/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.1914 - loss: 2.5907 - val_accuracy: 0.2188 - val_loss: 2.8010
# Epoch 101/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 172s 9s/step - accuracy: 0.2290 - loss: 2.5031 - val_accuracy: 0.2812 - val_loss: 2.8290
# Epoch 102/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 178s 9s/step - accuracy: 0.2117 - loss: 2.5093 - val_accuracy: 0.0938 - val_loss: 2.9917
# Epoch 103/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 179s 9s/step - accuracy: 0.2001 - loss: 2.6135 - val_accuracy: 0.1875 - val_loss: 2.8935
# Epoch 104/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 176s 9s/step - accuracy: 0.1940 - loss: 2.5377 - val_accuracy: 0.1562 - val_loss: 2.8684
# Epoch 105/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 9s/step - accuracy: 0.1730 - loss: 2.5094 - val_accuracy: 0.2188 - val_loss: 2.8998
# Epoch 106/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 172s 9s/step - accuracy: 0.2123 - loss: 2.6249 - val_accuracy: 0.2188 - val_loss: 2.8822
# Epoch 107/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 176s 9s/step - accuracy: 0.1784 - loss: 2.6750 - val_accuracy: 0.2188 - val_loss: 2.9693
# Epoch 108/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.2098 - loss: 2.5635 - val_accuracy: 0.2188 - val_loss: 2.8728
# Epoch 109/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.1789 - loss: 2.5854 - val_accuracy: 0.1875 - val_loss: 2.8532
# Epoch 110/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 163s 8s/step - accuracy: 0.2678 - loss: 2.5647 - val_accuracy: 0.2188 - val_loss: 2.8961
# Epoch 111/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2418 - loss: 2.5519 - val_accuracy: 0.2500 - val_loss: 2.8390
# Epoch 112/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2477 - loss: 2.4707 - val_accuracy: 0.1875 - val_loss: 2.9307
# Epoch 113/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.2712 - loss: 2.5671 - val_accuracy: 0.1562 - val_loss: 2.8910
# Epoch 114/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 176s 9s/step - accuracy: 0.2621 - loss: 2.3702 - val_accuracy: 0.1875 - val_loss: 2.9122
# Epoch 115/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.2478 - loss: 2.4889 - val_accuracy: 0.2188 - val_loss: 2.8685
# Epoch 116/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 164s 8s/step - accuracy: 0.2043 - loss: 2.6054 - val_accuracy: 0.2188 - val_loss: 2.8440
# Epoch 117/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 165s 8s/step - accuracy: 0.1744 - loss: 2.6394 - val_accuracy: 0.2188 - val_loss: 2.8209
# Epoch 118/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 231s 12s/step - accuracy: 0.2273 - loss: 2.6087 - val_accuracy: 0.2812 - val_loss: 2.7783
# Epoch 119/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 192s 9s/step - accuracy: 0.3296 - loss: 2.3445 - val_accuracy: 0.2500 - val_loss: 2.7852
# Epoch 120/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 192s 9s/step - accuracy: 0.2734 - loss: 2.3650 - val_accuracy: 0.2500 - val_loss: 2.7556
# Epoch 121/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 8s/step - accuracy: 0.3268 - loss: 2.4460 - val_accuracy: 0.2812 - val_loss: 2.8378
# Epoch 122/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.1804 - loss: 2.6587 - val_accuracy: 0.2188 - val_loss: 2.9291
# Epoch 123/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2929 - loss: 2.3661 - val_accuracy: 0.2812 - val_loss: 2.8739
# Epoch 124/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.1943 - loss: 2.5627 - val_accuracy: 0.2812 - val_loss: 2.8034
# Epoch 125/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2914 - loss: 2.5350 - val_accuracy: 0.2500 - val_loss: 2.7970
# Epoch 126/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2486 - loss: 2.4262 - val_accuracy: 0.3125 - val_loss: 2.8100
# Epoch 127/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3763 - loss: 2.2063 - val_accuracy: 0.3125 - val_loss: 2.8382
# Epoch 128/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2581 - loss: 2.4309 - val_accuracy: 0.1875 - val_loss: 2.9511
# Epoch 129/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2489 - loss: 2.5246 - val_accuracy: 0.2812 - val_loss: 2.7979
# Epoch 130/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 157s 8s/step - accuracy: 0.1878 - loss: 2.5585 - val_accuracy: 0.2812 - val_loss: 2.8033
# Epoch 131/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.1560 - loss: 2.5245 - val_accuracy: 0.2500 - val_loss: 2.9201
# Epoch 132/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2489 - loss: 2.3766 - val_accuracy: 0.2188 - val_loss: 2.8383
# Epoch 133/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2320 - loss: 2.5810 - val_accuracy: 0.2812 - val_loss: 2.7884
# Epoch 134/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.2342 - loss: 2.4321 - val_accuracy: 0.2812 - val_loss: 2.8825
# Epoch 135/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.2087 - loss: 2.5639 - val_accuracy: 0.1875 - val_loss: 2.8678
# Epoch 136/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.2473 - loss: 2.3798 - val_accuracy: 0.2188 - val_loss: 2.8702
# Epoch 137/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.2660 - loss: 2.4704 - val_accuracy: 0.2188 - val_loss: 3.0119
# Epoch 138/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2848 - loss: 2.3383 - val_accuracy: 0.2812 - val_loss: 2.7644
# Epoch 139/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2272 - loss: 2.4045 - val_accuracy: 0.2812 - val_loss: 2.7475
# Epoch 140/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2954 - loss: 2.3522 - val_accuracy: 0.2500 - val_loss: 2.7742
# Epoch 141/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3161 - loss: 2.2713 - val_accuracy: 0.2188 - val_loss: 2.8765
# Epoch 142/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2107 - loss: 2.4177 - val_accuracy: 0.3125 - val_loss: 2.7648
# Epoch 143/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.2733 - loss: 2.3900 - val_accuracy: 0.2812 - val_loss: 2.9547
# Epoch 144/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2348 - loss: 2.4909 - val_accuracy: 0.3750 - val_loss: 2.7918
# Epoch 145/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.1883 - loss: 2.4835 - val_accuracy: 0.2812 - val_loss: 2.7466
# Epoch 146/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.2621 - loss: 2.4733 - val_accuracy: 0.1875 - val_loss: 2.8766
# Epoch 147/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3286 - loss: 2.1471 - val_accuracy: 0.2812 - val_loss: 2.7967
# Epoch 148/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.2611 - loss: 2.2706 - val_accuracy: 0.2188 - val_loss: 2.7863
# Epoch 149/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2179 - loss: 2.4212 - val_accuracy: 0.2500 - val_loss: 2.8862
# Epoch 150/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 157s 8s/step - accuracy: 0.2210 - loss: 2.3443 - val_accuracy: 0.3125 - val_loss: 2.9712
# Epoch 151/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2428 - loss: 2.4778 - val_accuracy: 0.3438 - val_loss: 2.7447
# Epoch 152/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.2383 - loss: 2.3664 - val_accuracy: 0.3750 - val_loss: 2.7326
# Epoch 153/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2567 - loss: 2.4739 - val_accuracy: 0.2812 - val_loss: 2.8856
# Epoch 154/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3037 - loss: 2.4128 - val_accuracy: 0.3125 - val_loss: 2.9951
# Epoch 155/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.1915 - loss: 2.4831 - val_accuracy: 0.2500 - val_loss: 2.7721
# Epoch 156/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2268 - loss: 2.3752 - val_accuracy: 0.3750 - val_loss: 2.7747
# Epoch 157/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2868 - loss: 2.3949 - val_accuracy: 0.3438 - val_loss: 2.9326
# Epoch 158/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3282 - loss: 2.2806 - val_accuracy: 0.4062 - val_loss: 2.8116
# Epoch 159/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2913 - loss: 2.4095 - val_accuracy: 0.3125 - val_loss: 2.5715
# Epoch 160/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.2474 - loss: 2.4109 - val_accuracy: 0.3750 - val_loss: 2.6921
# Epoch 161/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2740 - loss: 2.3374 - val_accuracy: 0.2500 - val_loss: 2.8432
# Epoch 162/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.2257 - loss: 2.4242 - val_accuracy: 0.3438 - val_loss: 2.6394
# Epoch 163/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2209 - loss: 2.5991 - val_accuracy: 0.3438 - val_loss: 2.5681
# Epoch 164/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2804 - loss: 2.4613 - val_accuracy: 0.3750 - val_loss: 2.5796
# Epoch 165/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3021 - loss: 2.2018 - val_accuracy: 0.3125 - val_loss: 2.6638
# Epoch 166/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2034 - loss: 2.4362 - val_accuracy: 0.3750 - val_loss: 2.4972
# Epoch 167/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2648 - loss: 2.3791 - val_accuracy: 0.3125 - val_loss: 2.7002
# Epoch 168/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3342 - loss: 2.2175 - val_accuracy: 0.4062 - val_loss: 2.6120
# Epoch 169/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.2871 - loss: 2.4299 - val_accuracy: 0.3438 - val_loss: 2.7457
# Epoch 170/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2581 - loss: 2.3881 - val_accuracy: 0.3125 - val_loss: 2.6246
# Epoch 171/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.2454 - loss: 2.3331 - val_accuracy: 0.3125 - val_loss: 2.7119
# Epoch 172/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3188 - loss: 2.2508 - val_accuracy: 0.3438 - val_loss: 2.6875
# Epoch 173/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2673 - loss: 2.3488 - val_accuracy: 0.3438 - val_loss: 2.7950
# Epoch 174/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3021 - loss: 2.2909 - val_accuracy: 0.2812 - val_loss: 2.6278
# Epoch 175/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3321 - loss: 2.2510 - val_accuracy: 0.3438 - val_loss: 2.8144
# Epoch 176/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3827 - loss: 2.1082 - val_accuracy: 0.2812 - val_loss: 2.7362
# Epoch 177/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3158 - loss: 2.2778 - val_accuracy: 0.3125 - val_loss: 2.5654
# Epoch 178/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2343 - loss: 2.5352 - val_accuracy: 0.3125 - val_loss: 2.6926
# Epoch 179/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3506 - loss: 2.2363 - val_accuracy: 0.3438 - val_loss: 2.5574
# Epoch 180/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2826 - loss: 2.2255 - val_accuracy: 0.2500 - val_loss: 2.7035
# Epoch 181/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3499 - loss: 2.2631 - val_accuracy: 0.2812 - val_loss: 2.4691
# Epoch 182/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.2562 - loss: 2.2401 - val_accuracy: 0.3438 - val_loss: 2.5686
# Epoch 183/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.3017 - loss: 2.2516 - val_accuracy: 0.3750 - val_loss: 2.8049
# Epoch 184/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.2876 - loss: 2.3749 - val_accuracy: 0.3125 - val_loss: 2.7984
# Epoch 185/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2493 - loss: 2.2770 - val_accuracy: 0.2812 - val_loss: 2.7555
# Epoch 186/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2758 - loss: 2.3279 - val_accuracy: 0.3750 - val_loss: 2.5983
# Epoch 187/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.2972 - loss: 2.2992 - val_accuracy: 0.4062 - val_loss: 2.5838
# Epoch 188/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.2904 - loss: 2.2585 - val_accuracy: 0.3438 - val_loss: 2.6549
# Epoch 189/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3472 - loss: 2.1578 - val_accuracy: 0.3125 - val_loss: 2.6884
# Epoch 190/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3555 - loss: 2.1261 - val_accuracy: 0.4062 - val_loss: 2.4067
# Epoch 191/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.3278 - loss: 2.2077 - val_accuracy: 0.4062 - val_loss: 2.6577
# Epoch 192/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3212 - loss: 2.1697 - val_accuracy: 0.3438 - val_loss: 2.7354
# Epoch 193/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2590 - loss: 2.4360 - val_accuracy: 0.3125 - val_loss: 2.8473
# Epoch 194/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2933 - loss: 2.2990 - val_accuracy: 0.3750 - val_loss: 2.7061
# Epoch 195/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.3692 - loss: 2.1407 - val_accuracy: 0.4062 - val_loss: 2.8185
# Epoch 196/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2693 - loss: 2.2636 - val_accuracy: 0.4375 - val_loss: 2.5578
# Epoch 197/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3473 - loss: 2.1516 - val_accuracy: 0.3438 - val_loss: 2.7712
# Epoch 198/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3299 - loss: 2.1395 - val_accuracy: 0.3750 - val_loss: 2.7120
# Epoch 199/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.3146 - loss: 2.1201 - val_accuracy: 0.4375 - val_loss: 2.6337
# Epoch 200/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2151 - loss: 2.3779 - val_accuracy: 0.2812 - val_loss: 2.7126
# Epoch 201/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2655 - loss: 2.3499 - val_accuracy: 0.3125 - val_loss: 2.6580
# Epoch 202/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3135 - loss: 2.2717 - val_accuracy: 0.2812 - val_loss: 2.7841
# Epoch 203/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3217 - loss: 2.2978 - val_accuracy: 0.2500 - val_loss: 2.7947
# Epoch 204/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3976 - loss: 2.0801 - val_accuracy: 0.3750 - val_loss: 2.6088
# Epoch 205/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3622 - loss: 2.1212 - val_accuracy: 0.3125 - val_loss: 2.6353
# Epoch 206/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3111 - loss: 2.2554 - val_accuracy: 0.3125 - val_loss: 2.7642
# Epoch 207/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.4208 - loss: 2.0860 - val_accuracy: 0.2812 - val_loss: 2.8827
# Epoch 208/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3704 - loss: 2.0213 - val_accuracy: 0.2500 - val_loss: 2.9189
# Epoch 209/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.2439 - loss: 2.4349 - val_accuracy: 0.2812 - val_loss: 2.8386
# Epoch 210/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.2901 - loss: 2.1787 - val_accuracy: 0.3125 - val_loss: 2.7564
# Epoch 211/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3905 - loss: 1.9633 - val_accuracy: 0.3125 - val_loss: 2.6448
# Epoch 212/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.3350 - loss: 2.0852 - val_accuracy: 0.3125 - val_loss: 2.6242
# Epoch 213/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3662 - loss: 2.0705 - val_accuracy: 0.2500 - val_loss: 2.7241
# Epoch 214/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3334 - loss: 2.0445 - val_accuracy: 0.2812 - val_loss: 2.7901
# Epoch 215/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3886 - loss: 1.9649 - val_accuracy: 0.2812 - val_loss: 3.0048
# Epoch 216/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.3127 - loss: 2.1705 - val_accuracy: 0.2812 - val_loss: 3.0528
# Epoch 217/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3960 - loss: 2.0339 - val_accuracy: 0.4062 - val_loss: 2.8188
# Epoch 218/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3894 - loss: 2.1532 - val_accuracy: 0.3125 - val_loss: 2.8863
# Epoch 219/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.4194 - loss: 1.9587 - val_accuracy: 0.3438 - val_loss: 3.0107
# Epoch 220/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3378 - loss: 2.0729 - val_accuracy: 0.4062 - val_loss: 2.7917
# Epoch 221/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.4537 - loss: 1.7976 - val_accuracy: 0.3438 - val_loss: 3.0618
# Epoch 222/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3887 - loss: 2.0312 - val_accuracy: 0.4375 - val_loss: 2.8509
# Epoch 223/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 163s 8s/step - accuracy: 0.4110 - loss: 1.8465 - val_accuracy: 0.3125 - val_loss: 2.7699
# Epoch 224/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2851 - loss: 2.3114 - val_accuracy: 0.3750 - val_loss: 2.7730
# Epoch 225/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.2918 - loss: 2.1261 - val_accuracy: 0.3438 - val_loss: 2.8534
# Epoch 226/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.3422 - loss: 2.0874 - val_accuracy: 0.3125 - val_loss: 2.8189
# Epoch 227/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3197 - loss: 2.1260 - val_accuracy: 0.3125 - val_loss: 2.9833
# Epoch 228/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.4054 - loss: 2.0962 - val_accuracy: 0.3125 - val_loss: 3.0835
# Epoch 229/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.4036 - loss: 2.0384 - val_accuracy: 0.3438 - val_loss: 2.9504
# Epoch 230/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.3372 - loss: 2.0865 - val_accuracy: 0.3750 - val_loss: 2.9721
# Epoch 231/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.4249 - loss: 1.9394 - val_accuracy: 0.3750 - val_loss: 2.8070
# Epoch 232/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 164s 8s/step - accuracy: 0.3984 - loss: 1.9708 - val_accuracy: 0.3438 - val_loss: 2.9275
# Epoch 233/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.3566 - loss: 2.0674 - val_accuracy: 0.3438 - val_loss: 2.7648
# Epoch 234/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 164s 8s/step - accuracy: 0.3085 - loss: 2.1753 - val_accuracy: 0.3438 - val_loss: 2.7969
# Epoch 235/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.4088 - loss: 2.0672 - val_accuracy: 0.2500 - val_loss: 2.7636
# Epoch 236/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.4035 - loss: 2.1115 - val_accuracy: 0.3125 - val_loss: 2.8186
# Epoch 237/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.2401 - loss: 2.3686 - val_accuracy: 0.3125 - val_loss: 2.6799
# Epoch 238/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3437 - loss: 2.1087 - val_accuracy: 0.3750 - val_loss: 2.7485
# Epoch 239/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3608 - loss: 2.0484 - val_accuracy: 0.4375 - val_loss: 2.7990
# Epoch 240/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3486 - loss: 2.0303 - val_accuracy: 0.2812 - val_loss: 3.3047
# Epoch 241/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3502 - loss: 2.1327 - val_accuracy: 0.3438 - val_loss: 2.9395
# Epoch 242/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3849 - loss: 1.8787 - val_accuracy: 0.3750 - val_loss: 2.9364
# Epoch 243/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.4250 - loss: 1.8701 - val_accuracy: 0.4062 - val_loss: 2.9492
# Epoch 244/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3425 - loss: 2.0756 - val_accuracy: 0.2812 - val_loss: 2.8876
# Epoch 245/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3403 - loss: 2.1505 - val_accuracy: 0.3750 - val_loss: 2.9572
# Epoch 246/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.4408 - loss: 1.8560 - val_accuracy: 0.4062 - val_loss: 3.0337
# Epoch 247/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.3461 - loss: 2.1641 - val_accuracy: 0.3438 - val_loss: 3.1968
# Epoch 248/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 159s 8s/step - accuracy: 0.3290 - loss: 2.0357 - val_accuracy: 0.4062 - val_loss: 3.0414
# Epoch 249/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3626 - loss: 2.0311 - val_accuracy: 0.3750 - val_loss: 2.9589
# Epoch 250/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 157s 8s/step - accuracy: 0.3783 - loss: 2.0537 - val_accuracy: 0.3438 - val_loss: 3.3864
# Epoch 251/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3230 - loss: 1.9753 - val_accuracy: 0.2812 - val_loss: 3.4920
# Epoch 252/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3216 - loss: 2.0447 - val_accuracy: 0.4062 - val_loss: 2.7715
# Epoch 253/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.4028 - loss: 1.7827 - val_accuracy: 0.4062 - val_loss: 3.0521
# Epoch 254/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3584 - loss: 1.9272 - val_accuracy: 0.2812 - val_loss: 2.9986
# Epoch 255/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 163s 8s/step - accuracy: 0.3537 - loss: 2.1182 - val_accuracy: 0.2500 - val_loss: 2.8691
# Epoch 256/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3444 - loss: 2.0263 - val_accuracy: 0.2812 - val_loss: 3.0043
# Epoch 257/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.4401 - loss: 2.0159 - val_accuracy: 0.4062 - val_loss: 2.8894
# Epoch 258/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 163s 8s/step - accuracy: 0.3154 - loss: 2.1463 - val_accuracy: 0.2500 - val_loss: 2.9302
# Epoch 259/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3601 - loss: 2.1227 - val_accuracy: 0.2812 - val_loss: 3.0144
# Epoch 260/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3600 - loss: 2.1418 - val_accuracy: 0.4062 - val_loss: 2.7061
# Epoch 261/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 160s 8s/step - accuracy: 0.3819 - loss: 1.9370 - val_accuracy: 0.5312 - val_loss: 2.5851
# Epoch 262/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3507 - loss: 2.0373 - val_accuracy: 0.5312 - val_loss: 2.3437
# Epoch 263/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 162s 8s/step - accuracy: 0.3804 - loss: 2.1864 - val_accuracy: 0.3750 - val_loss: 2.9061
# Epoch 264/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 163s 8s/step - accuracy: 0.4182 - loss: 1.9497 - val_accuracy: 0.3750 - val_loss: 2.8054
# Epoch 265/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 161s 8s/step - accuracy: 0.3226 - loss: 2.1446 - val_accuracy: 0.3438 - val_loss: 3.2342
# Epoch 266/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 164s 8s/step - accuracy: 0.2648 - loss: 2.2607 - val_accuracy: 0.2500 - val_loss: 3.5225
# Epoch 267/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 164s 8s/step - accuracy: 0.3599 - loss: 2.0419 - val_accuracy: 0.3125 - val_loss: 3.3645
# Epoch 268/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 165s 8s/step - accuracy: 0.4017 - loss: 1.8536 - val_accuracy: 0.3438 - val_loss: 3.5667
# Epoch 269/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 164s 8s/step - accuracy: 0.4253 - loss: 2.0185 - val_accuracy: 0.3125 - val_loss: 3.6819
# Epoch 270/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 164s 8s/step - accuracy: 0.3806 - loss: 2.0073 - val_accuracy: 0.2500 - val_loss: 3.3469
# Epoch 271/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.4478 - loss: 1.9493 - val_accuracy: 0.3125 - val_loss: 3.3966
# Epoch 272/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - accuracy: 0.3693 - loss: 2.0217 - val_accuracy: 0.3438 - val_loss: 3.0564
# Epoch 273/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 167s 8s/step - accuracy: 0.4341 - loss: 1.9489 - val_accuracy: 0.3438 - val_loss: 3.3700
# Epoch 274/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.4265 - loss: 1.9930 - val_accuracy: 0.3438 - val_loss: 3.1714
# Epoch 275/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - accuracy: 0.3931 - loss: 1.9431 - val_accuracy: 0.3438 - val_loss: 2.9700
# Epoch 276/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 9s/step - accuracy: 0.3265 - loss: 2.0880 - val_accuracy: 0.3750 - val_loss: 2.9343
# Epoch 277/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 172s 8s/step - accuracy: 0.4331 - loss: 1.9696 - val_accuracy: 0.4062 - val_loss: 3.2781
# Epoch 278/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 8s/step - accuracy: 0.4259 - loss: 1.9510 - val_accuracy: 0.3750 - val_loss: 3.0190
# Epoch 279/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 164s 8s/step - accuracy: 0.3762 - loss: 1.9875 - val_accuracy: 0.3438 - val_loss: 3.2012
# Epoch 280/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.3778 - loss: 2.0526 - val_accuracy: 0.2500 - val_loss: 3.2201
# Epoch 281/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.3408 - loss: 2.0884 - val_accuracy: 0.2812 - val_loss: 3.0035
# Epoch 282/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.3966 - loss: 2.0591 - val_accuracy: 0.3125 - val_loss: 2.7586
# Epoch 283/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - accuracy: 0.3606 - loss: 2.1043 - val_accuracy: 0.3438 - val_loss: 3.0763
# Epoch 284/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.3234 - loss: 2.0528 - val_accuracy: 0.3750 - val_loss: 3.1665
# Epoch 285/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 8s/step - accuracy: 0.3723 - loss: 2.0631 - val_accuracy: 0.2812 - val_loss: 3.2579
# Epoch 286/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.3840 - loss: 2.0662 - val_accuracy: 0.3750 - val_loss: 2.7618
# Epoch 287/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 168s 8s/step - accuracy: 0.3831 - loss: 2.0689 - val_accuracy: 0.3438 - val_loss: 3.1245
# Epoch 288/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.4378 - loss: 1.8684 - val_accuracy: 0.3125 - val_loss: 3.6170
# Epoch 289/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.4163 - loss: 1.9648 - val_accuracy: 0.3125 - val_loss: 3.3729
# Epoch 290/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 169s 8s/step - accuracy: 0.3918 - loss: 1.9246 - val_accuracy: 0.2500 - val_loss: 3.8579
# Epoch 291/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 174s 9s/step - accuracy: 0.3637 - loss: 1.9918 - val_accuracy: 0.3438 - val_loss: 3.6577
# Epoch 292/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 172s 8s/step - accuracy: 0.3693 - loss: 2.1432 - val_accuracy: 0.3438 - val_loss: 3.4122
# Epoch 293/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 173s 9s/step - accuracy: 0.3956 - loss: 1.9547 - val_accuracy: 0.3125 - val_loss: 3.4984
# Epoch 294/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 172s 8s/step - accuracy: 0.4248 - loss: 1.8245 - val_accuracy: 0.3750 - val_loss: 3.1951
# Epoch 295/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.3292 - loss: 2.1021 - val_accuracy: 0.2500 - val_loss: 3.6055
# Epoch 296/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.3255 - loss: 2.0959 - val_accuracy: 0.3125 - val_loss: 3.6350
# Epoch 297/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 174s 9s/step - accuracy: 0.4071 - loss: 2.0955 - val_accuracy: 0.3438 - val_loss: 3.1362
# Epoch 298/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 176s 9s/step - accuracy: 0.3569 - loss: 1.9731 - val_accuracy: 0.3438 - val_loss: 3.3196
# Epoch 299/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 171s 9s/step - accuracy: 0.3613 - loss: 1.9628 - val_accuracy: 0.4062 - val_loss: 3.0443
# Epoch 300/300
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 170s 8s/step - accuracy: 0.4329 - loss: 1.8785 - val_accuracy: 0.4062 - val_loss: 2.9549
#
# Saving learning curves graph . . .

# %%
from tensorflow.keras.models import load_model

# model settings
height = 224
width = 224
dim = (height, width)
batch_size = 8
frames = 10
channels = 3
output = 20

TEST_PATH = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_20\test\\'
# transform labels from string to number
labels = labels_to_number(TEST_PATH)
# load dataset as dict
y_test_dict = videos_to_dict(TEST_PATH, labels)
# get video paths (without labels)
X_test = list(y_test_dict.keys())

# load the best model after training
last = load_model(r'C:\Users\anany\Downloads\saved_models\best_model.keras')

# instantiation of the model with best model's weights
model = create_model_wlasl20c(frames, width, height, channels, output)
model.compile(optimizer=last.optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.set_weights(last.get_weights())

# instantiation of test generator
print('\nTest generator')
test_generator = VideoFrameGenerator(
    list_IDs=X_test,
    labels=y_test_dict,
    batch_size=batch_size,
    dim=dim,
    n_channels=channels,
    n_sequence=frames,
    shuffle=False,
    type_gen='test'
)

# evaluate the best model on test set
print('\nEvaluating the best model on test set . . .')
eval_loss, eval_acc = model.evaluate(test_generator)

print(f'\nFinal Test Accuracy: {eval_acc * 100:.2f}%')
# Out:
# C:\Users\anany\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Test generator
# Videos: 26, batches per epoch: 3
#
# Evaluating the best model on test set . . .
# C:\Users\anany\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.3646 - loss: 2.3923
#
# Final Test Accuracy: 41.67%

# %%
import threading

import cv2
import numpy as np
from tensorflow.keras.models import load_model

# global variables
gloss_show = 'Word: none'
labels = {
    0: 'book',
    1: 'chair',
    2: 'clothes',
    3: 'computer',
    4: 'drink',
    5: 'drum',
    6: 'family',
    7: 'football',
    8: 'go',
    9: 'hat',
    10: 'hello',
    11: 'kiss',
    12: 'like',
    13: 'play',
    14: 'school',
    15: 'street',
    16: 'table',
    17: 'university',
    18: 'violin',
    19: 'wall'
}


def main():
    # settings
    dim = (224, 224)
    frames = 10
    channels = 3
    model_path = r'C:\Users\anany\Downloads\saved_models\best_model.keras'
    threshold = .50

    print("ASL Real-time Recognition\n")
    print("[INFO] initializing ...")
    # define empty buffer
    frame_buffer = np.empty((0, *dim, channels))

    print("[INFO] loading ASL detection model ...")
    # load model
    model = load_model(model_path)

    print("[INFO] starting video stream ...")
    # start the video stream
    cap = cv2.VideoCapture(1)
    cap.set(cv2.CAP_PROP_FPS, 25)  # set the FPS to 25

    x = threading.Thread()
    # loop over the frames
    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            # process the frame
            frame_res = cv2.resize(frame, dim)
            frame_res = frame_res / 255.0
            # append the frame to buffer
            frame_resh = np.reshape(frame_res, (1, *frame_res.shape))
            frame_buffer = np.append(frame_buffer, frame_resh, axis=0)
            # start sign recognition only if the buffer is full
            if frame_buffer.shape[0] == frames:
                # make the prediction
                if not x.is_alive():
                    x = threading.Thread(target=make_prediction, args=(
                        frame_buffer, model, threshold))
                    x.start()
                else:
                    pass
                # left-shift of the buffer
                frame_buffer = frame_buffer[1:frames]
                # show label
                font = cv2.FONT_HERSHEY_SIMPLEX
                cv2.putText(frame, gloss_show, (20, 450), font, 1, (0, 255, 0),
                            2, cv2.LINE_AA)
                cv2.imshow('frame', frame)

            # press Q to exit
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            break

    cap.release()


def make_prediction(frame_buffer, model, threshold):
    global gloss_show

    frame_buffer_resh = frame_buffer.reshape(1, *frame_buffer.shape)
    # model prediction
    predictions = model.predict(frame_buffer_resh)[0]
    # get the best prediction
    best_pred_idx = np.argmax(predictions)
    acc_best_pred = predictions[best_pred_idx]
    # check mislabeling
    if acc_best_pred > threshold:
        gloss = labels[best_pred_idx]
        gloss_show = "Word: {: <3}  {:.2f}% ".format(
            gloss,
            acc_best_pred * 100)
        print(gloss_show)
    else:
        gloss_show = 'Word: none'


if __name__ == '__main__':
    main()
# Out:
# ASL Real-time Recognition
#
# [INFO] initializing ...
# [INFO] loading ASL detection model ...
# [INFO] starting video stream ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Word: like  62.07%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  59.57%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  65.44%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Word: like  67.62%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Word: like  67.32%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Word: like  68.63%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Word: like  65.27%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  63.40%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Word: like  58.19%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Word: like  60.85%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Word: like  58.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Word: like  65.14%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  67.54%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Word: like  68.38%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  59.42%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  50.71%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Word: like  53.53%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  56.75%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  59.44%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Word: like  56.43%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  60.08%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  65.12%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Word: like  72.33%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  75.54%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Word: like  74.81%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  75.89%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  76.32%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Word: like  76.49%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Word: like  71.98%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  71.64%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Word: like  67.49%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Word: like  66.33%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Word: like  58.55%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  70.27%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Word: like  66.29%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Word: like  53.58%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  65.59%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Word: like  71.63%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  66.34%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Word: like  67.14%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Word: like  65.03%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  66.11%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Word: like  67.48%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  68.64%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  69.17%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Word: like  68.71%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Word: like  67.42%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Word: like  69.49%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Word: like  71.17%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  72.35%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  72.91%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  74.47%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Word: like  65.81%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Word: like  57.13%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Word: like  67.44%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Word: like  58.72%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Word: like  60.28%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Word: like  72.47%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Word: like  69.63%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  69.49%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  67.59%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Word: like  61.06%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  61.22%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# Word: like  69.06%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  65.62%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  66.60%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Word: like  64.41%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Word: like  68.25%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Word: like  64.80%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  61.16%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  65.13%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Word: like  67.50%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  63.85%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  61.41%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  59.37%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  63.60%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Word: like  65.13%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Word: like  52.76%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  54.24%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Word: like  56.54%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Word: like  60.51%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Word: like  63.72%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  69.28%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Word: like  67.67%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Word: like  71.87%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  73.99%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  73.71%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  72.71%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Word: like  70.69%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Word: like  74.16%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Word: like  70.53%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Word: like  67.29%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Word: like  66.08%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  68.54%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  69.60%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  65.09%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Word: like  63.41%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Word: like  62.43%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Word: like  62.50%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Word: like  61.70%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# Word: like  57.65%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  55.03%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Word: like  62.76%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Word: like  54.43%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Word: like  62.18%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Word: like  64.89%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Word: like  72.46%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Word: like  74.19%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Word: like  74.49%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  72.97%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  73.71%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  73.59%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Word: like  71.09%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Word: like  71.08%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  70.27%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Word: like  67.62%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  66.75%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  67.79%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Word: like  60.85%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Word: like  67.95%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Word: like  66.55%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Word: like  65.97%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  66.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Word: like  71.97%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  68.97%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  72.29%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Word: like  58.96%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  50.37%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Word: like  55.85%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Word: like  69.76%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Word: like  66.70%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# Word: like  63.39%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  61.74%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Word: like  60.34%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  58.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  66.48%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Word: like  64.79%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Word: like  62.48%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  61.43%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Word: like  62.14%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Word: like  64.70%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Word: like  62.04%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Word: like  59.71%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Word: like  64.35%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Word: like  57.46%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Word: like  70.81%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  68.60%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Word: like  73.85%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Word: like  74.79%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# Word: like  75.83%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Word: like  74.66%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Word: like  67.85%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Word: like  56.36%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Word: like  60.02%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Word: like  62.03%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Word: like  55.02%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Word: like  55.11%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  62.96%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Word: like  65.10%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: chair  61.64%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Word: chair  79.71%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# Word: chair  64.97%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Word: like  61.36%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Word: like  69.15%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Word: like  67.02%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Word: like  62.15%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Word: like  61.19%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  61.34%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Word: like  64.42%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Word: like  61.17%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Word: like  66.30%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Word: like  70.60%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Word: like  70.32%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Word: like  67.42%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Word: like  67.39%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Word: like  68.01%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Word: like  68.93%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Word: like  55.55%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Word: like  69.63%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Word: like  66.62%

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
import os

# Global variable for displaying the predicted word
gloss_show = 'Word: none'

# ASL labels for prediction (you should have the same as in your trained model)
labels = {
    0: 'book',
    1: 'chair',
    2: 'clothes',
    3: 'computer',
    4: 'drink',
    5: 'drum',
    6: 'family',
    7: 'football',
    8: 'go',
    9: 'hat',
    10: 'hello',
    11: 'kiss',
    12: 'like',
    13: 'play',
    14: 'school',
    15: 'street',
    16: 'table',
    17: 'university',
    18: 'violin',
    19: 'wall'
}

def predict_sign_from_video(video_path, model, frames=10, threshold=0.5):
    # Settings
    dim = (224, 224)  # Frame size
    channels = 3      # Number of channels (RGB)
    frame_buffer = np.empty((0, *dim, channels))  # Empty frame buffer for collecting frames

    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break  # Exit if there are no more frames in the video

        # Resize the frame to match model input
        frame_res = cv2.resize(frame, dim)
        frame_res = frame_res / 255.0  # Normalize to [0, 1]

        # Append frame to the buffer
        frame_resh = np.reshape(frame_res, (1, *frame_res.shape))
        frame_buffer = np.append(frame_buffer, frame_resh, axis=0)

        # Start prediction once the buffer is full
        if frame_buffer.shape[0] == frames:
            make_prediction(frame_buffer, model, threshold)

            # Left shift the buffer (remove the oldest frame)
            frame_buffer = frame_buffer[1:frames]

        # Display the prediction on the frame
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(frame, gloss_show, (20, 450), font, 1, (0, 255, 0), 2, cv2.LINE_AA)
        cv2.imshow('Video Prediction', frame)

        # Press 'q' to exit the video display
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

def make_prediction(frame_buffer, model, threshold):
    global gloss_show

    # Reshape the frame buffer and make predictions
    frame_buffer_resh = frame_buffer.reshape(1, *frame_buffer.shape)
    predictions = model.predict(frame_buffer_resh)[0]

    # Get the index of the highest prediction
    best_pred_idx = np.argmax(predictions)
    acc_best_pred = predictions[best_pred_idx]

    # If confidence is above threshold, display the predicted word
    if acc_best_pred > threshold:
        gloss = labels[best_pred_idx]
        gloss_show = "Word: {: <3}  {:.2f}%".format(gloss, acc_best_pred * 100)
        print(gloss_show)  # Print the prediction to the console
    else:
        gloss_show = 'Word: none'

if __name__ == '__main__':
    model_path = r'C:\Users\anany\Downloads\saved_models\best_model.keras'  # Path to your trained model
    video_path = r"C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_20\val\chair\09851.mp4"  # Path to the video file you want to analyze

    # Load the trained model
    print("[INFO] Loading model...")
    model = load_model(model_path)

    # Predict the sign from the provided video
    print("[INFO] Starting video prediction...")
    predict_sign_from_video(video_path, model)
# Out:
# [INFO] Loading model...
# [INFO] Starting video prediction...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Word: table  56.68%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Word: table  57.77%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Word: table  54.83%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step

# %%
#Text to Sign - Playing Videos
import os
import cv2
import random

# Path to the root folder where test/train/val folders are located
root_folder = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_20'  # Replace with the actual path to your dataset

import os
import random

def get_random_video_from_word(word, root_folder):
    """
    Function to get a random video from the word_label folder.
    
    :param word: The class or label (like 'dog' or 'cat')
    :param root_folder: The root folder where 'test', 'train', and 'val' are stored
    :return: A random video path from the specified word label folder
    """
    # Define the path to the test folder (or train/val as needed)
    test_folder = os.path.join(root_folder, 'train', word)
    
    # Check if the folder exists
    if not os.path.exists(test_folder):
        raise FileNotFoundError(f"The folder for word '{word}' does not exist in {test_folder}")
    
    # Get a list of all video files in the folder
    video_files = [f for f in os.listdir(test_folder) if f.endswith('.mp4')]
    
    # Check if there are any videos in the folder
    if not video_files:
        raise FileNotFoundError(f"No video files found in the folder: {test_folder}")
    
    # Randomly select a video from the list
    selected_video = random.choice(video_files)
    
    # Return the full path of the selected video
    return os.path.join(test_folder, selected_video)


def play_videos(video_paths):
    """
    Play a list of videos sequentially.
    """
    for video_path in video_paths:
        if not video_path:
            continue
        print(f"Playing video: {video_path}")

        # Open video
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Error: Could not open video {video_path}")
            continue

        # Get video properties
        fps = cap.get(cv2.CAP_PROP_FPS)
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break  # End of video

            # Display the frame
            cv2.imshow('Video Player', frame)

            # Wait for 'q' key press to exit the video early
            if cv2.waitKey(int(1000 / fps)) & 0xFF == ord('q'):
                break

        cap.release()

    cv2.destroyAllWindows()

def process_input_sentence(sentence):
    """
    Process input sentence and return associated video paths.
    """
    words = sentence.split()
    video_paths = []

    for word in words:
        video_path = get_random_video_from_word(word, root_folder)
        if video_path:
            video_paths.append(video_path)
    
    return video_paths

if __name__ == '__main__':
    # Input sentence
    sentence = input("Enter a sentence: ")

    # Process the sentence to get associated video paths
    video_paths = process_input_sentence(sentence)

    # Play the videos sequentially
    if video_paths:
        play_videos(video_paths)
    else:
        print("No videos found for the given sentence.")
# Out:
# Playing video: C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_20\train\book\07074.mp4
# Playing video: C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_20\train\computer\12327.mp4

# %%
import os
from itertools import islice

import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam


# model settings
height = 224
width = 224
dim = (height, width)
batch_size = 8
frames = 10
channels = 3
output = 2000

TRAIN_PATH = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_2000\train\\'
VAL_PATH = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_2000\val\\'
TEST_PATH = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_2000\test\\'

# transform labels from string to number
labels = labels_to_number(TRAIN_PATH)
print(f'Labels: {labels}')

# load dataset as dict
y_train_dict = videos_to_dict(TRAIN_PATH, labels)
y_val_dict = videos_to_dict(VAL_PATH, labels)
y_test_dict = videos_to_dict(TEST_PATH, labels)

print(f'\nTrain set: {len(y_train_dict)} videos - with labels')
print(f'Val   set: {len(y_val_dict)} videos - with labels')
print(f'Test  set: {len(y_test_dict)} videos - with labels')
print(f'Train set samples: {list(islice(y_train_dict.items(), 3))}')
print(f'Val   set samples: {list(islice(y_val_dict.items(), 3))}')
print(f'Test  set samples: {list(islice(y_test_dict.items(), 3))}')

# get video paths (without labels)
X_train = list(y_train_dict.keys())
X_val = list(y_val_dict.keys())
X_test = list(y_test_dict.keys())

print(f'\nTrain set: {len(X_train)} videos')
print(f'Val   set: {len(X_val)} videos')
print(f'Test  set: {len(X_test)} videos')
print(f'Train set samples: {X_train[:4]}')
print(f'Val   set samples: {X_val[:4]}')
print(f'Test  set samples: {X_test[:4]}')

# instantiation of generators for train and val sets
print('\nTrain generator')
train_generator = VideoFrameGenerator(
    list_IDs=X_train,
    labels=y_train_dict,
    batch_size=batch_size,
    dim=dim,
    n_channels=3,
    n_sequence=frames,
    shuffle=True,
    type_gen='train'
)

print('\nVal generator')
val_generator = VideoFrameGenerator(
    list_IDs=X_val,
    labels=y_val_dict,
    batch_size=batch_size,
    dim=dim,
    n_channels=3,
    n_sequence=frames,
    shuffle=True,
    type_gen='val'
)

# model building
print('\nModel building and compiling . . .')
model = create_model_wlasl2000(frames, width, height, channels, output)
model.summary()
# model compiling
adam = Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-07,
            amsgrad=False, name="Adam")
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

# callbacks creation
if not os.path.isdir('./saved_models/'):
    os.mkdir('./saved_models/')

# save the best model each time
path = './saved_models/'
checkpoint_cb = ModelCheckpoint(path + 'best_model_2000.keras', save_best_only=True)

# start training
print('\nStart training . . .')
learn_epochs = 10
history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=learn_epochs,
                    callbacks=[checkpoint_cb])

# save learning curves
if not os.path.isdir('./plots/'):
    os.mkdir('./plots/')

print('\nSaving learning curves graph . . .')
pd.DataFrame(history.history).plot(figsize=(9, 6))
plt.grid(True)
plt.gca().set_ylim(0, 4)
plt.savefig('./plots/learning_curves.png')

# %%
from tensorflow.keras.models import load_model

# model settings
height = 224
width = 224
dim = (height, width)
batch_size = 8
frames = 10
channels = 3
output = 2000

TEST_PATH = r'C:\Users\anany\Downloads\WLASL-dataset-sample\WLASL_2000\test\\'
# transform labels from string to number
labels = labels_to_number(TEST_PATH)
# load dataset as dict
y_test_dict = videos_to_dict(TEST_PATH, labels)
# get video paths (without labels)
X_test = list(y_test_dict.keys())

# load the best model after training
last = load_model(r'C:\Users\anany\Downloads\saved_models\best_model_2000.keras')

# instantiation of the model with best model's weights
model = create_model_wlasl20c(frames, width, height, channels, output)
model.compile(optimizer=last.optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.set_weights(last.get_weights())

# instantiation of test generator
print('\nTest generator')
test_generator = VideoFrameGenerator(
    list_IDs=X_test,
    labels=y_test_dict,
    batch_size=batch_size,
    dim=dim,
    n_channels=channels,
    n_sequence=frames,
    shuffle=False,
    type_gen='test'
)

# evaluate the best model on test set
print('\nEvaluating the best model on test set . . .')
eval_loss, eval_acc = model.evaluate(test_generator)

print(f'\nFinal Test Accuracy: {eval_acc * 100:.2f}%')
